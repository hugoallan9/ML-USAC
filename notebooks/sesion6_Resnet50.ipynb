# %% [markdown]
# # Uso del Modelo Resnet50
# Usando las imágenes del banco CIFAR-10 se utilizará el modelo preentrenado Resnet50.
# https://github.com/YoongiKim/CIFAR-10-images

# %%
import os
import keras
import pickle
import tensorflow as tf
import numpy as np

# %%
def resnet50_model(classes = 1000, *args, **kwargs):
    # Load a model if we have saved one
    if(os.path.isfile('/home/hugog/resnet_50.h5') == True):
        return keras.models.load_model('/home/hugog/resnet_50.h5')
    # Create an input layer
    input = keras.layers.Input(shape=(None, None, 3))
    # Create output layers
    output = keras.layers.ZeroPadding2D(padding=3, name='padding_conv1')(input)
    output = keras.layers.Conv2D(64, (7, 7), strides=(2, 2), use_bias=False, name='conv1')(output)
    output = keras.layers.BatchNormalization(axis=3, epsilon=1e-5, name='bn_conv1')(output)
    output = keras.layers.Activation('relu', name='conv1_relu')(output)
    output = keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same', name='pool1')(output)
    output = conv_block(output, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    output = identity_block(output, 3, [64, 64, 256], stage=2, block='b')
    output = identity_block(output, 3, [64, 64, 256], stage=2, block='c')
    output = conv_block(output, 3, [128, 128, 512], stage=3, block='a')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='b')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='c')
    output = identity_block(output, 3, [128, 128, 512], stage=3, block='d')
    output = conv_block(output, 3, [256, 256, 1024], stage=4, block='a')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='b')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='c')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='d')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='e')
    output = identity_block(output, 3, [256, 256, 1024], stage=4, block='f')
    output = conv_block(output, 3, [512, 512, 2048], stage=5, block='a')
    output = identity_block(output, 3, [512, 512, 2048], stage=5, block='b')
    output = identity_block(output, 3, [512, 512, 2048], stage=5, block='c')
    output = keras.layers.GlobalAveragePooling2D(name='pool5')(output)
    output = keras.layers.Dense(classes, activation='softmax', name='fc1000')(output)
    # Create a model from input layer and output layers
    model = keras.models.Model(inputs=input, outputs=output, *args, **kwargs)
    # Print model
    print()
    print(model.summary(), '\n')
    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), metrics=['accuracy'])
    # Return a model
    return model
# Create an identity block
def identity_block(input, kernel_size, filters, stage, block):

    # Variables
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    # Create layers
    output = keras.layers.Conv2D(filters1, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2a')(input)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name_base + '2b')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2c')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(output)
    output = keras.layers.add([output, input])
    output = keras.layers.Activation('relu')(output)
    # Return a block
    return output
# Create a convolution block
def conv_block(input, kernel_size, filters, stage, block, strides=(2, 2)):
    # Variables
    filters1, filters2, filters3 = filters
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    # Create block layers
    output = keras.layers.Conv2D(filters1, (1, 1), strides=strides, kernel_initializer='he_normal', name=conv_name_base + '2a')(input)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2a')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters2, kernel_size, padding='same', kernel_initializer='he_normal', name=conv_name_base + '2b')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2b')(output)
    output = keras.layers.Activation('relu')(output)
    output = keras.layers.Conv2D(filters3, (1, 1), kernel_initializer='he_normal', name=conv_name_base + '2c')(output)
    output = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '2c')(output)
    shortcut = keras.layers.Conv2D(filters3, (1, 1), strides=strides, kernel_initializer='he_normal', name=conv_name_base + '1')(input)
    shortcut = keras.layers.BatchNormalization(axis=3, name=bn_name_base + '1')(shortcut)
    output = keras.layers.add([output, shortcut])
    output = keras.layers.Activation('relu')(output)
    # Return a block
    return output
# Train a model
def train():
    # Variables, 25 epochs so far
    epochs = 1
    batch_size = 32
    train_samples = 10 * 5000 # 10 categories with 5000 images in each category
    validation_samples = 10 * 1000 # 10 categories with 1000 images in each category
    img_width, img_height = 32, 32
    # Get the model (10 categories)
    model = resnet50_model(10)
    # Create a data generator for training
    train_data_generator = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
    # Create a data generator for validation
    validation_data_generator = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)
    # Create a train generator
    train_generator = train_data_generator.flow_from_directory(
        '/home/hugog/GitHub/ML-USAC/data/CIFAR-10-images-master/train',
        target_size=(img_width, img_height),
        batch_size=batch_size,
        color_mode='rgb',
        shuffle=True,
        class_mode='categorical')
    # Create a test generator
    validation_generator = validation_data_generator.flow_from_directory(
        '/home/hugog/GitHub/ML-USAC/data/CIFAR-10-images-master/test',
        target_size=(img_width, img_height),
        batch_size=batch_size,
        color_mode='rgb',
        shuffle=True,
        class_mode='categorical')
    # Start training, fit the model
    model.fit_generator(
        train_generator,
        steps_per_epoch=train_samples // batch_size,
        validation_data=validation_generator,
        validation_steps=validation_samples // batch_size,
        epochs=epochs)
    # Save model to disk
    model.save('/home/hugog/resnet_50.h5')
    print('Saved model to disk!')
    # Get labels
    labels = train_generator.class_indices
    # Invert labels
    classes = {}
    for key, value in labels.items():
        classes[value] = key.capitalize()
    # Save classes to file
    with open('/home/hugog/classes.pkl', 'wb') as file:
        pickle.dump(classes, file)
    print('Saved classes to disk!')
# The main entry point for this module
def main():
    # Train a model
    train()
# Tell python to run main method
if __name__ == '__main__': main()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, None, None,  0           []
#                                  3)]
#
#  padding_conv1 (ZeroPadding2D)  (None, None, None,   0           ['input_6[0][0]']
#                                 3)
#
#  conv1 (Conv2D)                 (None, None, None,   9408        ['padding_conv1[0][0]']
#                                 64)
#
#  bn_conv1 (BatchNormalization)  (None, None, None,   256         ['conv1[0][0]']
#                                 64)
#
#  conv1_relu (Activation)        (None, None, None,   0           ['bn_conv1[0][0]']
#                                 64)
#
#  pool1 (MaxPooling2D)           (None, None, None,   0           ['conv1_relu[0][0]']
#                                 64)
#
#  res2a_branch2a (Conv2D)        (None, None, None,   4160        ['pool1[0][0]']
#                                 64)
#
#  bn2a_branch2a (BatchNormalizat  (None, None, None,   256        ['res2a_branch2a[0][0]']
#  ion)                           64)
#
#  activation_240 (Activation)    (None, None, None,   0           ['bn2a_branch2a[0][0]']
#                                 64)
#
#  res2a_branch2b (Conv2D)        (None, None, None,   36928       ['activation_240[0][0]']
#                                 64)
#
#  bn2a_branch2b (BatchNormalizat  (None, None, None,   256        ['res2a_branch2b[0][0]']
#  ion)                           64)
#
#  activation_241 (Activation)    (None, None, None,   0           ['bn2a_branch2b[0][0]']
#                                 64)
#
#  res2a_branch2c (Conv2D)        (None, None, None,   16640       ['activation_241[0][0]']
#                                 256)
#
#  res2a_branch1 (Conv2D)         (None, None, None,   16640       ['pool1[0][0]']
#                                 256)
#
#  bn2a_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2a_branch2c[0][0]']
#  ion)                           256)
#
#  bn2a_branch1 (BatchNormalizati  (None, None, None,   1024       ['res2a_branch1[0][0]']
#  on)                            256)
#
#  add_80 (Add)                   (None, None, None,   0           ['bn2a_branch2c[0][0]',
#                                 256)                              'bn2a_branch1[0][0]']
#
#  activation_242 (Activation)    (None, None, None,   0           ['add_80[0][0]']
#                                 256)
#
#  res2b_branch2a (Conv2D)        (None, None, None,   16448       ['activation_242[0][0]']
#                                 64)
#
#  bn2b_branch2a (BatchNormalizat  (None, None, None,   256        ['res2b_branch2a[0][0]']
#  ion)                           64)
#
#  activation_243 (Activation)    (None, None, None,   0           ['bn2b_branch2a[0][0]']
#                                 64)
#
#  res2b_branch2b (Conv2D)        (None, None, None,   36928       ['activation_243[0][0]']
#                                 64)
#
#  bn2b_branch2b (BatchNormalizat  (None, None, None,   256        ['res2b_branch2b[0][0]']
#  ion)                           64)
#
#  activation_244 (Activation)    (None, None, None,   0           ['bn2b_branch2b[0][0]']
#                                 64)
#
#  res2b_branch2c (Conv2D)        (None, None, None,   16640       ['activation_244[0][0]']
#                                 256)
#
#  bn2b_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2b_branch2c[0][0]']
#  ion)                           256)
#
#  add_81 (Add)                   (None, None, None,   0           ['bn2b_branch2c[0][0]',
#                                 256)                              'activation_242[0][0]']
#
#  activation_245 (Activation)    (None, None, None,   0           ['add_81[0][0]']
#                                 256)
#
#  res2c_branch2a (Conv2D)        (None, None, None,   16448       ['activation_245[0][0]']
#                                 64)
#
#  bn2c_branch2a (BatchNormalizat  (None, None, None,   256        ['res2c_branch2a[0][0]']
#  ion)                           64)
#
#  activation_246 (Activation)    (None, None, None,   0           ['bn2c_branch2a[0][0]']
#                                 64)
#
#  res2c_branch2b (Conv2D)        (None, None, None,   36928       ['activation_246[0][0]']
#                                 64)
#
#  bn2c_branch2b (BatchNormalizat  (None, None, None,   256        ['res2c_branch2b[0][0]']
#  ion)                           64)
#
#  activation_247 (Activation)    (None, None, None,   0           ['bn2c_branch2b[0][0]']
#                                 64)
#
#  res2c_branch2c (Conv2D)        (None, None, None,   16640       ['activation_247[0][0]']
#                                 256)
#
#  bn2c_branch2c (BatchNormalizat  (None, None, None,   1024       ['res2c_branch2c[0][0]']
#  ion)                           256)
#
#  add_82 (Add)                   (None, None, None,   0           ['bn2c_branch2c[0][0]',
#                                 256)                              'activation_245[0][0]']
#
#  activation_248 (Activation)    (None, None, None,   0           ['add_82[0][0]']
#                                 256)
#
#  res3a_branch2a (Conv2D)        (None, None, None,   32896       ['activation_248[0][0]']
#                                 128)
#
#  bn3a_branch2a (BatchNormalizat  (None, None, None,   512        ['res3a_branch2a[0][0]']
#  ion)                           128)
#
#  activation_249 (Activation)    (None, None, None,   0           ['bn3a_branch2a[0][0]']
#                                 128)
#
#  res3a_branch2b (Conv2D)        (None, None, None,   147584      ['activation_249[0][0]']
#                                 128)
#
#  bn3a_branch2b (BatchNormalizat  (None, None, None,   512        ['res3a_branch2b[0][0]']
#  ion)                           128)
#
#  activation_250 (Activation)    (None, None, None,   0           ['bn3a_branch2b[0][0]']
#                                 128)
#
#  res3a_branch2c (Conv2D)        (None, None, None,   66048       ['activation_250[0][0]']
#                                 512)
#
#  res3a_branch1 (Conv2D)         (None, None, None,   131584      ['activation_248[0][0]']
#                                 512)
#
#  bn3a_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3a_branch2c[0][0]']
#  ion)                           512)
#
#  bn3a_branch1 (BatchNormalizati  (None, None, None,   2048       ['res3a_branch1[0][0]']
#  on)                            512)
#
#  add_83 (Add)                   (None, None, None,   0           ['bn3a_branch2c[0][0]',
#                                 512)                              'bn3a_branch1[0][0]']
#
#  activation_251 (Activation)    (None, None, None,   0           ['add_83[0][0]']
#                                 512)
#
#  res3b_branch2a (Conv2D)        (None, None, None,   65664       ['activation_251[0][0]']
#                                 128)
#
#  bn3b_branch2a (BatchNormalizat  (None, None, None,   512        ['res3b_branch2a[0][0]']
#  ion)                           128)
#
#  activation_252 (Activation)    (None, None, None,   0           ['bn3b_branch2a[0][0]']
#                                 128)
#
#  res3b_branch2b (Conv2D)        (None, None, None,   147584      ['activation_252[0][0]']
#                                 128)
#
#  bn3b_branch2b (BatchNormalizat  (None, None, None,   512        ['res3b_branch2b[0][0]']
#  ion)                           128)
#
#  activation_253 (Activation)    (None, None, None,   0           ['bn3b_branch2b[0][0]']
#                                 128)
#
#  res3b_branch2c (Conv2D)        (None, None, None,   66048       ['activation_253[0][0]']
#                                 512)
#
#  bn3b_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3b_branch2c[0][0]']
#  ion)                           512)
#
#  add_84 (Add)                   (None, None, None,   0           ['bn3b_branch2c[0][0]',
#                                 512)                              'activation_251[0][0]']
#
#  activation_254 (Activation)    (None, None, None,   0           ['add_84[0][0]']
#                                 512)
#
#  res3c_branch2a (Conv2D)        (None, None, None,   65664       ['activation_254[0][0]']
#                                 128)
#
#  bn3c_branch2a (BatchNormalizat  (None, None, None,   512        ['res3c_branch2a[0][0]']
#  ion)                           128)
#
#  activation_255 (Activation)    (None, None, None,   0           ['bn3c_branch2a[0][0]']
#                                 128)
#
#  res3c_branch2b (Conv2D)        (None, None, None,   147584      ['activation_255[0][0]']
#                                 128)
#
#  bn3c_branch2b (BatchNormalizat  (None, None, None,   512        ['res3c_branch2b[0][0]']
#  ion)                           128)
#
#  activation_256 (Activation)    (None, None, None,   0           ['bn3c_branch2b[0][0]']
#                                 128)
#
#  res3c_branch2c (Conv2D)        (None, None, None,   66048       ['activation_256[0][0]']
#                                 512)
#
#  bn3c_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3c_branch2c[0][0]']
#  ion)                           512)
#
#  add_85 (Add)                   (None, None, None,   0           ['bn3c_branch2c[0][0]',
#                                 512)                              'activation_254[0][0]']
#
#  activation_257 (Activation)    (None, None, None,   0           ['add_85[0][0]']
#                                 512)
#
#  res3d_branch2a (Conv2D)        (None, None, None,   65664       ['activation_257[0][0]']
#                                 128)
#
#  bn3d_branch2a (BatchNormalizat  (None, None, None,   512        ['res3d_branch2a[0][0]']
#  ion)                           128)
#
#  activation_258 (Activation)    (None, None, None,   0           ['bn3d_branch2a[0][0]']
#                                 128)
#
#  res3d_branch2b (Conv2D)        (None, None, None,   147584      ['activation_258[0][0]']
#                                 128)
#
#  bn3d_branch2b (BatchNormalizat  (None, None, None,   512        ['res3d_branch2b[0][0]']
#  ion)                           128)
#
#  activation_259 (Activation)    (None, None, None,   0           ['bn3d_branch2b[0][0]']
#                                 128)
#
#  res3d_branch2c (Conv2D)        (None, None, None,   66048       ['activation_259[0][0]']
#                                 512)
#
#  bn3d_branch2c (BatchNormalizat  (None, None, None,   2048       ['res3d_branch2c[0][0]']
#  ion)                           512)
#
#  add_86 (Add)                   (None, None, None,   0           ['bn3d_branch2c[0][0]',
#                                 512)                              'activation_257[0][0]']
#
#  activation_260 (Activation)    (None, None, None,   0           ['add_86[0][0]']
#                                 512)
#
#  res4a_branch2a (Conv2D)        (None, None, None,   131328      ['activation_260[0][0]']
#                                 256)
#
#  bn4a_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4a_branch2a[0][0]']
#  ion)                           256)
#
#  activation_261 (Activation)    (None, None, None,   0           ['bn4a_branch2a[0][0]']
#                                 256)
#
#  res4a_branch2b (Conv2D)        (None, None, None,   590080      ['activation_261[0][0]']
#                                 256)
#
#  bn4a_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4a_branch2b[0][0]']
#  ion)                           256)
#
#  activation_262 (Activation)    (None, None, None,   0           ['bn4a_branch2b[0][0]']
#                                 256)
#
#  res4a_branch2c (Conv2D)        (None, None, None,   263168      ['activation_262[0][0]']
#                                 1024)
#
#  res4a_branch1 (Conv2D)         (None, None, None,   525312      ['activation_260[0][0]']
#                                 1024)
#
#  bn4a_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4a_branch2c[0][0]']
#  ion)                           1024)
#
#  bn4a_branch1 (BatchNormalizati  (None, None, None,   4096       ['res4a_branch1[0][0]']
#  on)                            1024)
#
#  add_87 (Add)                   (None, None, None,   0           ['bn4a_branch2c[0][0]',
#                                 1024)                             'bn4a_branch1[0][0]']
#
#  activation_263 (Activation)    (None, None, None,   0           ['add_87[0][0]']
#                                 1024)
#
#  res4b_branch2a (Conv2D)        (None, None, None,   262400      ['activation_263[0][0]']
#                                 256)
#
#  bn4b_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4b_branch2a[0][0]']
#  ion)                           256)
#
#  activation_264 (Activation)    (None, None, None,   0           ['bn4b_branch2a[0][0]']
#                                 256)
#
#  res4b_branch2b (Conv2D)        (None, None, None,   590080      ['activation_264[0][0]']
#                                 256)
#
#  bn4b_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4b_branch2b[0][0]']
#  ion)                           256)
#
#  activation_265 (Activation)    (None, None, None,   0           ['bn4b_branch2b[0][0]']
#                                 256)
#
#  res4b_branch2c (Conv2D)        (None, None, None,   263168      ['activation_265[0][0]']
#                                 1024)
#
#  bn4b_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4b_branch2c[0][0]']
#  ion)                           1024)
#
#  add_88 (Add)                   (None, None, None,   0           ['bn4b_branch2c[0][0]',
#                                 1024)                             'activation_263[0][0]']
#
#  activation_266 (Activation)    (None, None, None,   0           ['add_88[0][0]']
#                                 1024)
#
#  res4c_branch2a (Conv2D)        (None, None, None,   262400      ['activation_266[0][0]']
#                                 256)
#
#  bn4c_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4c_branch2a[0][0]']
#  ion)                           256)
#
#  activation_267 (Activation)    (None, None, None,   0           ['bn4c_branch2a[0][0]']
#                                 256)
#
#  res4c_branch2b (Conv2D)        (None, None, None,   590080      ['activation_267[0][0]']
#                                 256)
#
#  bn4c_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4c_branch2b[0][0]']
#  ion)                           256)
#
#  activation_268 (Activation)    (None, None, None,   0           ['bn4c_branch2b[0][0]']
#                                 256)
#
#  res4c_branch2c (Conv2D)        (None, None, None,   263168      ['activation_268[0][0]']
#                                 1024)
#
#  bn4c_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4c_branch2c[0][0]']
#  ion)                           1024)
#
#  add_89 (Add)                   (None, None, None,   0           ['bn4c_branch2c[0][0]',
#                                 1024)                             'activation_266[0][0]']
#
#  activation_269 (Activation)    (None, None, None,   0           ['add_89[0][0]']
#                                 1024)
#
#  res4d_branch2a (Conv2D)        (None, None, None,   262400      ['activation_269[0][0]']
#                                 256)
#
#  bn4d_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4d_branch2a[0][0]']
#  ion)                           256)
#
#  activation_270 (Activation)    (None, None, None,   0           ['bn4d_branch2a[0][0]']
#                                 256)
#
#  res4d_branch2b (Conv2D)        (None, None, None,   590080      ['activation_270[0][0]']
#                                 256)
#
#  bn4d_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4d_branch2b[0][0]']
#  ion)                           256)
#
#  activation_271 (Activation)    (None, None, None,   0           ['bn4d_branch2b[0][0]']
#                                 256)
#
#  res4d_branch2c (Conv2D)        (None, None, None,   263168      ['activation_271[0][0]']
#                                 1024)
#
#  bn4d_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4d_branch2c[0][0]']
#  ion)                           1024)
#
#  add_90 (Add)                   (None, None, None,   0           ['bn4d_branch2c[0][0]',
#                                 1024)                             'activation_269[0][0]']
#
#  activation_272 (Activation)    (None, None, None,   0           ['add_90[0][0]']
#                                 1024)
#
#  res4e_branch2a (Conv2D)        (None, None, None,   262400      ['activation_272[0][0]']
#                                 256)
#
#  bn4e_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4e_branch2a[0][0]']
#  ion)                           256)
#
#  activation_273 (Activation)    (None, None, None,   0           ['bn4e_branch2a[0][0]']
#                                 256)
#
#  res4e_branch2b (Conv2D)        (None, None, None,   590080      ['activation_273[0][0]']
#                                 256)
#
#  bn4e_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4e_branch2b[0][0]']
#  ion)                           256)
#
#  activation_274 (Activation)    (None, None, None,   0           ['bn4e_branch2b[0][0]']
#                                 256)
#
#  res4e_branch2c (Conv2D)        (None, None, None,   263168      ['activation_274[0][0]']
#                                 1024)
#
#  bn4e_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4e_branch2c[0][0]']
#  ion)                           1024)
#
#  add_91 (Add)                   (None, None, None,   0           ['bn4e_branch2c[0][0]',
#                                 1024)                             'activation_272[0][0]']
#
#  activation_275 (Activation)    (None, None, None,   0           ['add_91[0][0]']
#                                 1024)
#
#  res4f_branch2a (Conv2D)        (None, None, None,   262400      ['activation_275[0][0]']
#                                 256)
#
#  bn4f_branch2a (BatchNormalizat  (None, None, None,   1024       ['res4f_branch2a[0][0]']
#  ion)                           256)
#
#  activation_276 (Activation)    (None, None, None,   0           ['bn4f_branch2a[0][0]']
#                                 256)
#
#  res4f_branch2b (Conv2D)        (None, None, None,   590080      ['activation_276[0][0]']
#                                 256)
#
#  bn4f_branch2b (BatchNormalizat  (None, None, None,   1024       ['res4f_branch2b[0][0]']
#  ion)                           256)
#
#  activation_277 (Activation)    (None, None, None,   0           ['bn4f_branch2b[0][0]']
#                                 256)
#
#  res4f_branch2c (Conv2D)        (None, None, None,   263168      ['activation_277[0][0]']
#                                 1024)
#
#  bn4f_branch2c (BatchNormalizat  (None, None, None,   4096       ['res4f_branch2c[0][0]']
#  ion)                           1024)
#
#  add_92 (Add)                   (None, None, None,   0           ['bn4f_branch2c[0][0]',
#                                 1024)                             'activation_275[0][0]']
#
#  activation_278 (Activation)    (None, None, None,   0           ['add_92[0][0]']
#                                 1024)
#
#  res5a_branch2a (Conv2D)        (None, None, None,   524800      ['activation_278[0][0]']
#                                 512)
#
#  bn5a_branch2a (BatchNormalizat  (None, None, None,   2048       ['res5a_branch2a[0][0]']
#  ion)                           512)
#
#  activation_279 (Activation)    (None, None, None,   0           ['bn5a_branch2a[0][0]']
#                                 512)
#
#  res5a_branch2b (Conv2D)        (None, None, None,   2359808     ['activation_279[0][0]']
#                                 512)
#
#  bn5a_branch2b (BatchNormalizat  (None, None, None,   2048       ['res5a_branch2b[0][0]']
#  ion)                           512)
#
#  activation_280 (Activation)    (None, None, None,   0           ['bn5a_branch2b[0][0]']
#                                 512)
#
#  res5a_branch2c (Conv2D)        (None, None, None,   1050624     ['activation_280[0][0]']
#                                 2048)
#
#  res5a_branch1 (Conv2D)         (None, None, None,   2099200     ['activation_278[0][0]']
#                                 2048)
#
#  bn5a_branch2c (BatchNormalizat  (None, None, None,   8192       ['res5a_branch2c[0][0]']
#  ion)                           2048)
#
#  bn5a_branch1 (BatchNormalizati  (None, None, None,   8192       ['res5a_branch1[0][0]']
#  on)                            2048)
#
#  add_93 (Add)                   (None, None, None,   0           ['bn5a_branch2c[0][0]',
#                                 2048)                             'bn5a_branch1[0][0]']
#
#  activation_281 (Activation)    (None, None, None,   0           ['add_93[0][0]']
#                                 2048)
#
#  res5b_branch2a (Conv2D)        (None, None, None,   1049088     ['activation_281[0][0]']
#                                 512)
#
#  bn5b_branch2a (BatchNormalizat  (None, None, None,   2048       ['res5b_branch2a[0][0]']
#  ion)                           512)
#
#  activation_282 (Activation)    (None, None, None,   0           ['bn5b_branch2a[0][0]']
#                                 512)
#
#  res5b_branch2b (Conv2D)        (None, None, None,   2359808     ['activation_282[0][0]']
#                                 512)
#
#  bn5b_branch2b (BatchNormalizat  (None, None, None,   2048       ['res5b_branch2b[0][0]']
#  ion)                           512)
#
#  activation_283 (Activation)    (None, None, None,   0           ['bn5b_branch2b[0][0]']
#                                 512)
#
#  res5b_branch2c (Conv2D)        (None, None, None,   1050624     ['activation_283[0][0]']
#                                 2048)
#
#  bn5b_branch2c (BatchNormalizat  (None, None, None,   8192       ['res5b_branch2c[0][0]']
#  ion)                           2048)
#
#  add_94 (Add)                   (None, None, None,   0           ['bn5b_branch2c[0][0]',
#                                 2048)                             'activation_281[0][0]']
#
#  activation_284 (Activation)    (None, None, None,   0           ['add_94[0][0]']
#                                 2048)
#
#  res5c_branch2a (Conv2D)        (None, None, None,   1049088     ['activation_284[0][0]']
#                                 512)
#
#  bn5c_branch2a (BatchNormalizat  (None, None, None,   2048       ['res5c_branch2a[0][0]']
#  ion)                           512)
#
#  activation_285 (Activation)    (None, None, None,   0           ['bn5c_branch2a[0][0]']
#                                 512)
#
#  res5c_branch2b (Conv2D)        (None, None, None,   2359808     ['activation_285[0][0]']
#                                 512)
#
#  bn5c_branch2b (BatchNormalizat  (None, None, None,   2048       ['res5c_branch2b[0][0]']
#  ion)                           512)
#
#  activation_286 (Activation)    (None, None, None,   0           ['bn5c_branch2b[0][0]']
#                                 512)
#
#  res5c_branch2c (Conv2D)        (None, None, None,   1050624     ['activation_286[0][0]']
#                                 2048)
#
#  bn5c_branch2c (BatchNormalizat  (None, None, None,   8192       ['res5c_branch2c[0][0]']
#  ion)                           2048)
#
#  add_95 (Add)                   (None, None, None,   0           ['bn5c_branch2c[0][0]',
#                                 2048)                             'activation_284[0][0]']
#
#  activation_287 (Activation)    (None, None, None,   0           ['add_95[0][0]']
#                                 2048)
#
#  pool5 (GlobalAveragePooling2D)  (None, 2048)        0           ['activation_287[0][0]']
#
#  fc1000 (Dense)                 (None, 10)           20490       ['pool5[0][0]']
#
# ==================================================================================================
# Total params: 23,608,138
# Trainable params: 23,555,018
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None
#
# Found 50000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
# /tmp/ipykernel_255321/4085684511.py:120: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(
#  171/1562 [==>...........................] - ETA: 24:56 - loss: 5.8176 - accuracy: 0.1149
